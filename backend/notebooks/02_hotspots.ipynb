# %% [markdown]
# # Hotspot & Gap Analysis
#
# This notebook identifies over-sampled hotspots and under-sampled gaps.
#
# **Owner:** TBD
#
# ## Objectives
# - Implement H3 hexagonal binning
# - Calculate observation density per hex
# - Compute biodiversity yield metrics
# - Identify over-sampled hotspots
# - Detect under-sampled gaps

# %%
import pandas as pd
import geopandas as gpd
import h3
import matplotlib.pyplot as plt

# TODO: Implement hexagonal binning
# TODO: Calculate density metrics
# TODO: Identify hotspots and gaps
# TODO: Visualize results on map
